# %%
from scipy.io import loadmat
import numpy as np
import matplotlib.pyplot as plt


filename = "/home3/luharj/AiSteth/Training_Data/New folder/14998_MV"
label_info = loadmat(f'{filename}.mat')
# print(data_info)




# Samplerate 50 Hz labels
label_info = label_info['PCG_states'][0]
print(label_info.shape)


label_info = label_info[:100]
# Retrieving the S1 tags
s1_labels = (label_info == 1)
systole_labels = (label_info == 2)
s2_labels = (label_info == 3)
diastole_labels = (label_info == 4)


time = np.arange(0, len(label_info)) / 50
plt.figure(figsize=(14, 3))
plt.plot(time, label_info)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.savefig("signal.png")
plt.show()
# Out:
# (1135,)
